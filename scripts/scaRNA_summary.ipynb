# %%
import json
import pandas as pd
import plotly.express as px

# %%
samples = [
    "test",
]

# %% [markdown]
# ## trim summary

# %%
json_dir = "../data/output/json/"
with open(f"{json_dir}/{samples[0]}.trim.json", "r") as f:
    data = json.load(f)

trim_df = pd.DataFrame(index=samples, columns=data.keys())
for sample in samples:
    with open(f"{json_dir}/{sample}.trim.json", "r") as f:
        trim_df.loc[sample] = json.load(f)

trim_df_per = trim_df.copy()
for col in trim_df_per.columns:
    trim_df_per[col] = trim_df_per[col] / trim_df["total"] * 100

trim_df = trim_df[["without_primer", "no_insert", "yes_insert"]]
trim_df_per = trim_df_per[["without_primer", "no_insert", "yes_insert"]]
trim_df = trim_df.reset_index().melt(id_vars="index")
trim_df.columns = ["sample", "type", "count"]
trim_df_per = trim_df_per.reset_index().melt(id_vars="index")
trim_df_per["value"] = trim_df_per["value"].apply(lambda x: round(x, 2))
trim_df_per.columns = ["sample", "type", "percent"]
trim_df_per["count"] = trim_df["count"].apply(lambda x: f"{x/1e6:.2f}M")

# %%
for sample, sub_df in trim_df.groupby("sample"):
    seq_volume = trim_df.loc[trim_df["sample"] == sample, "count"].sum()
    print(f"{sample}: {seq_volume*300/1e9:.1f} Gb")
# Out:
# test: 0.3 Gb

# %%
fig = px.bar(
    trim_df_per,
    x="sample",
    y="percent",
    color="type",
    text="count",
    # text_auto=True,
    barmode="stack",
    title="Trim results",
    labels={"sample": ""},
)
fig.show()
# Out:
# <div>                            <div id="9551c5e0-d9b1-4f93-8b88-c44dafa47131" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9551c5e0-d9b1-4f93-8b88-c44dafa47131")) {                    Plotly.newPlot(                        "9551c5e0-d9b1-4f93-8b88-c44dafa47131",                        [{"alignmentgroup":"True","hovertemplate":"type=without_primer\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"without_primer","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"without_primer","offsetgroup":"without_primer","orientation":"v","showlegend":true,"text":["0.67M"],"textposition":"auto","x":["test"],"xaxis":"x","y":[67.03],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=no_insert\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"no_insert","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"no_insert","offsetgroup":"no_insert","orientation":"v","showlegend":true,"text":["0.00M"],"textposition":"auto","x":["test"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=yes_insert\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"yes_insert","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"yes_insert","offsetgroup":"yes_insert","orientation":"v","showlegend":true,"text":["0.33M"],"textposition":"auto","x":["test"],"xaxis":"x","y":[32.96],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colors ...

# %% [markdown]
# ## mapping summary

# %%
map_rrna = pd.DataFrame(
    columns=["unmapped", "rRNA", "miRNA", "snoRNA", "snRNA", "other_mapped", "mRNA", "mRNA_tss"],
)
for sample in samples:
    with open(f"{json_dir}/{sample}.summary.json", "r") as f:
        map_rrna.loc[sample] = json.load(f)
# convert to percentage per row
map_rrna_per = map_rrna.copy()
map_rrna_per = map_rrna_per.apply(lambda x: x / x.sum() * 100, axis=1)
map_rrna_per = map_rrna_per.reset_index().melt(id_vars="index")
map_rrna_per["value"] = map_rrna_per["value"].apply(lambda x: round(x, 2))
map_rrna_per.columns = ["sample", "type", "percent"]
map_rrna = map_rrna.reset_index().melt(id_vars="index")
map_rrna.columns = ["sample", "type", "count"]
map_rrna_per["count"] = map_rrna["count"].apply(lambda x: f"{x/1e6:.1f}M") + map_rrna_per[
    "percent"
].apply(lambda x: f"({x:.1f}%)")

# %%
fig = px.bar(
    map_rrna_per,
    x="sample",
    y="percent",
    color="type",
    barmode="stack",
    title="Map results",
    labels={"sample": ""},
    text="count",
)
fig.show()
# Out:
# <div>                            <div id="93cf309a-fcb8-4e4d-a9fd-e54399762ac4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93cf309a-fcb8-4e4d-a9fd-e54399762ac4")) {                    Plotly.newPlot(                        "93cf309a-fcb8-4e4d-a9fd-e54399762ac4",                        [{"alignmentgroup":"True","hovertemplate":"type=unmapped\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unmapped","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"unmapped","offsetgroup":"unmapped","orientation":"v","showlegend":true,"text":["0.1M(6.3%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[6.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=rRNA\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rRNA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"rRNA","offsetgroup":"rRNA","orientation":"v","showlegend":true,"text":["0.0M(0.9%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[0.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=miRNA\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"miRNA","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"miRNA","offsetgroup":"miRNA","orientation":"v","showlegend":true,"text":["0.0M(0.1%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[0.12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=snoRNA\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"snoRNA","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"snoRNA","offsetgroup":"snoRNA","orientation":"v","showlegend":true,"text":["0.0M(3.9%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[3.93],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=snRNA\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"snRNA","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"snRNA","offsetgroup":"snRNA","orientation":"v","showlegend":true,"text":["0.6M(58.3%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[58.27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=other_mapped\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"other_mapped","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"other_mapped","offsetgroup":"other_mapped","orientation":"v","showlegend":true,"text":["0.1M(7.8%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[7.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=mRNA\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mRNA","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"mRNA","offsetgroup":"mRNA","orientation":"v","showlegend":true,"text":["0.1M(5.4%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[5.38],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=mRNA_tss\u003cbr\u003e=%{x}\u003cbr\u003epercent=%{y}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mRNA_tss","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"mRNA_tss","offsetgroup":"mRNA_tss","orientation":"v","showlegend":true,"text":["0.2M(17.4%)"],"textposition":"auto","x":["test"],"xaxis":"x","y":[17.36],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour" ...

# %% [markdown]
# ## insert size

# %%
bed_dir = "../data/interim/bed/"
insert_size = []
for sample in samples:
    df = pd.read_csv(f"{bed_dir}/{sample}_frags.sort.mRNA_tss.bed", sep="\t", header=None)
    if len(df) >= 100000:
        df = df.sample(100000)

    df["insert_size"] = df[2] - df[1]
    df = df[(df["insert_size"] <= 500) & (df["insert_size"] > 0)]
    df["sample"] = sample
    insert_size.append(df[["insert_size", "sample"]].copy())
insert_size = pd.concat(insert_size, ignore_index=True)

# %%
import plotly.graph_objects as go
from plotly.colors import n_colors

colors = n_colors("rgb(5, 200, 200)", "rgb(200, 10, 10)", len(samples)+1, colortype="rgb")

fig = go.Figure()
for sample, color in zip(samples, colors):
    fig.add_trace(
        go.Violin(
            x=insert_size[insert_size["sample"] == sample]["insert_size"].values, line_color=color
        )
    )

fig.update_traces(orientation="h", side="positive", width=3, points=False)
# fig.update_layout(xaxis_showgrid=False, xaxis_zeroline=False)
# rename y ticks
fig.update_layout(
    yaxis=dict(
        tickmode="array",
        tickvals=list(range(len(samples))),
        ticktext=samples,
    )
)
# disable legend
fig.update_layout(showlegend=False)
fig.update_layout(title="Insert size distribution")
fig.show()
# Out:
# <div>                            <div id="5eb9ca18-b548-4863-9939-205a3d290084" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5eb9ca18-b548-4863-9939-205a3d290084")) {                    Plotly.newPlot(                        "5eb9ca18-b548-4863-9939-205a3d290084",                        [{"line":{"color":"rgb(5.0, 200.0, 200.0)"},"x":[42,125,29,216,47,72,370,20,204,110,60,57,77,54,39,24,102,119,142,102,51,13,31,21,84,28,25,22,18,29,31,36,19,40,39,40,208,82,30,98,128,78,162,152,30,211,28,112,79,170,111,142,185,82,80,52,38,112,43,52,153,130,47,29,208,62,78,99,185,104,69,70,89,21,62,72,24,79,147,67,78,208,35,55,44,91,70,139,104,74,50,47,208,110,269,48,90,46,79,208,25,72,18,207,119,13,34,18,106,47,74,72,85,146,35,73,82,200,37,192,94,102,69,139,43,208,60,208,72,27,72,17,33,31,69,74,73,35,56,103,41,93,15,76,20,144,100,109,211,108,199,208,81,253,74,74,67,266,148,120,66,89,65,117,105,211,169,74,93,39,118,208,208,82,28,74,208,144,125,93,25,77,19,48,214,82,81,60,133,81,16,208,176,76,59,208,117,123,20,103,80,33,93,96,74,99,51,48,26,31,72,82,47,92,208,50,208,51,57,24,38,64,208,95,47,140,19,74,25,74,20,105,192,260,226,82,74,82,82,207,103,57,117,54,141,22,73,30,168,43,46,48,75,14,153,309,82,34,24,78,111,74,116,100,74,169,77,74,215,68,62,66,147,37,208,498,172,113,208,30,41,31,76,130,82,137,79,67,18,53,69,35,30,73,84,51,29,208,119,107,17,18,75,208,118,120,76,179,76,81,30,208,